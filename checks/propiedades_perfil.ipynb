# %% [markdown]
# ## Propiedades de perfiles
#
# Script para presentar propiedades de perfiles

# %%
import pandas as pd
df = pd.read_csv('database/perfiles_SI.csv', sep=',')

# %%
# Out:
#       Type   PERFIL_AISC PERFIL_METRICO      W       A       d    ddet  Ht  \
# 0        W       W44X335      W1100X499  499.0   63500  1120.0  1120.0 NaN
# 1        W       W44X290      W1100X433  433.0   55100  1110.0  1110.0 NaN
# 2        W       W44X262      W1100X390  390.0   49800  1100.0  1100.0 NaN
# 3        W       W44X230      W1100X343  343.0   43700  1090.0  1090.0 NaN
# 4        W       W40X655      W1000X976  975.0  125000  1110.0  1110.0 NaN
# ...    ...           ...            ...    ...     ...     ...     ...  ..
# 2086  PIPE      Pipe5XXS     Pipe125XXS   57.4    6900     NaN     NaN NaN
# 2087  PIPE      Pipe4XXS     Pipe100XXS   41.0    4940     NaN     NaN NaN
# 2088  PIPE      Pipe3XXS      Pipe80XXS   27.7    3340     NaN     NaN NaN
# 2089  PIPE  Pipe2-1/2XXS      Pipe65XXS   20.4    2470     NaN     NaN NaN
# 2090  PIPE      Pipe2XXS      Pipe50XXS   13.4    1620     NaN     NaN NaN
#
# ...
